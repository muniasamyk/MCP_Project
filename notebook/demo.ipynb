# %% [markdown]
# # MCP Agent Demo
#
# This notebook demonstrates the Model Context Protocol (MCP) agent in action.
# It uses a secure Orchestrator to Plan, Execute, and Reason about database queries.

# %%
import sys
import os
import json

# Add project root to path so we can import 'app'
project_root = os.path.abspath('..')
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from app.agents.orchestrator import AgentOrchestrator

print("✅ Imports ready!")
# Out:
# ✅ Imports ready!

# %%
# Initialize the Agent Orchestrator
# This automatically sets up the Planner, Executor, and Reasoner agents
agent = AgentOrchestrator()
# Out:
# 2026-02-12 10:21:16,308 | INFO | app.agents.orchestrator | Orchestrator ready (Provider: ollama)

# %%
query = "Fetch employee details where department is AI?"

result = agent.process_query(query)

print(f"p> Query: {query}")
print(f"> Answer: {result.get('explanation')}")
print(f"> Data: {json.dumps(result.get('data'), indent=2, default=str)}")
# Out:
# 2026-02-12 10:21:17,042 | INFO | app.agents.planner_agent | Planning for query: 'Fetch employee details where department is AI?'
# 2026-02-12 10:21:17,042 | INFO | app.agents.llm_provider | Ollama (llama3): Generating...
# 2026-02-12 10:23:34,196 | INFO | app.agents.planner_agent | Selected tool: get_employees_by_department with params: {'department': 'AI'}
# 2026-02-12 10:23:34,198 | INFO | app.agents.executor_agent | Executing tool: get_employees_by_department
# 2026-02-12 10:23:34,198 | INFO | app.mcp.tools | Tool: Get employees (dept=AI)
# 2026-02-12 10:23:34,199 | INFO | app.database.db_executor | Initializing DB connection pool...
# 2026-02-12 10:23:34,336 | INFO | app.database.db_executor | Executing SQL: SELECT id, name, email, department, salary FROM employees WHERE LOWER(department) = LOWER(%s) | Params: ('AI',)
# 2026-02-12 10:23:34,388 | INFO | app.database.db_executor | Query returned 16 rows
# 2026-02-12 10:23:34,391 | INFO | app.agents.reasoner_agent | Generating explanation...
# 2026-02-12 10:23:34,393 | INFO | app.agents.llm_provider | Ollama (llama3): Generating...
# 2026-02-12 10:26:36,445 | ERROR | app.agents.llm_provider | Ollama failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# 2026-02-12 10:26:36,448 | ERROR | app.agents.reasoner_agent | Reasoning failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# p> Query: Fetch employee details where department is AI?
# > Answer: Here is the raw data: [{'id': 1, 'name': 'Alice Johnson', 'email': 'alice@company.com', 'department': 'AI', 'salary': Decimal('95000.00')}, {'id': 2, 'name': 'Bob Smith', 'email': 'bob@company.com', 'department': 'AI', 'salary': Decimal('92000.00')}, {'id': 5, 'name': 'Eva Martinez', 'email': 'eva@company.com', 'department': 'AI', 'salary': Decimal('98000.00')}, {'id': 9, 'name': 'Alice Johnson', 'email': 'alice.johnson@company.com', 'department': 'AI', 'salary': Decimal('95000.00')}, {'id': 10, 'name': 'Bob Smith', 'email': 'bob.smith@company.com', 'department': 'AI', 'salary': Decimal('92000.00')}, {'id': 13, 'name': 'Eva Martinez', 'email': 'eva.martinez@company.com', 'department': 'AI', 'salary': Decimal('98000.00')}, {'id': 17, 'name': 'Irene Adams', 'email': 'irene.adams@company.com', 'department': 'AI', 'salary': Decimal('96000.00')}, {'id': 21, 'name': 'Mona Scott', 'email': 'mona.scott@company.com', 'department': 'AI', 'salary': Decimal('97000.00')}, {'id': 25, 'name': 'Queen Roberts', 'email': 'queen.roberts@company.com', 'department': 'AI', 'salary': Decimal('99000.00')}, {'id': 29, 'name': 'Uma Patel', 'email': 'uma.patel@company.com', 'department': 'AI', 'salary': Decimal('94000.00')}, {'id': 33, 'name': 'Yara Khan', 'email': 'yara.khan@company.com', 'department': 'AI', 'salary': Decimal('96500.00')}, {'id': 35, 'name': 'Amit Sharma', 'email': 'amit.sharma@company.com', 'department': 'AI', 'salary': Decimal('93000.00')}, {'id': 39, 'name': 'Esha Mehta', 'email': 'esha.mehta@company.com', 'department': 'AI', 'salary': Decimal('95500.00')}, {'id': 43, 'name': 'Isha Kapoor', 'email': 'isha.kapoor@company.com', 'department': 'AI', 'salary': Decimal('96000.00')}, {'id': 47, 'name': 'Meena Das', 'email': 'meena.das@company.com', 'department': 'AI', 'salary': Decimal('97000.00')}, {'id': 50, 'name': 'Priya Reddy', 'email': 'priya.reddy@company.com', 'department': 'AI', 'salary': Decimal('95000.00')}]
# > Data: [
#   {
#     "id": 1,
#     "name": "Alice Johnson",
#     "email": "alice@company.com",
#     "department": "AI",
#     "salary": "95000.00"
#   },
#   {
#     "id": 2,
#     "name": "Bob Smith",
#     "email": "bob@company.com",
#     "department": "AI",
#     "salary": "92000.00"
#   },
#   {
#     "id": 5,
#     "name": "Eva Martinez",
#     "email": "eva@company.com",
#     "department": "AI",
#     "salary": "98000.00"
#   },
#   {
#     "id": 9,
#     "name": "Alice Johnson",
#     "email": "alice.johnson@company.com",
#     "department": "AI",
#     "salary": "95000.00"
#   },
#   {
#     "id": 10,
#     "name": "Bob Smith",
#     "email": "bob.smith@company.com",
#     "department": "AI",
#     "salary": "92000.00"
#   },
#   {
#     "id": 13,
#     "name": "Eva Martinez",
#     "email": "eva.martinez@company.com",
#     "department": "AI",
#     "salary": "98000.00"
#   },
#   {
#     "id": 17,
#     "name": "Irene Adams",
#     "email": "irene.adams@company.com",
#     "department": "AI",
#     "salary": "96000.00"
#   },
#   {
#     "id": 21,
#     "name": "Mona Scott",
#     "email": "mona.scott@company.com",
#     "department": "AI",
#     "salary": "97000.00"
#   },
#   {
#     "id": 25,
#     "name": "Queen Roberts",
#     "email": "queen.roberts@company.com",
#     "department": "AI",
#     "salary": "99000.00"
#   },
#   {
#     "id": 29,
#     "name": "Uma Patel",
#     "email": "uma.patel@company.com",
#     "department": "AI",
#     "salary": "94000.00"
#   },
#   {
#     "id": 33,
#     "name": "Yara Khan",
#     "email": "yara.khan@company.com",
#     "department": "AI",
#     "salary": "96500.00"
#   },
#   {
#     "id": 35,
#     "name": "Amit Sharma",
#     "email": "amit.sharma@company.com",
#     "department": "AI",
#     "salary": "93000.00"
#   },
#   {
#     "id": 39,
#     "name": "Esha Mehta",
#     "email": "esha.mehta@company.com",
#     "department": "AI",
#     "salary": "95500.00"
#   },
#   {
#     "id": 43,
#     "name": "Isha Kapoor",
#     "email": "isha.kapoor@company.com",
#     "department": "AI",
#     "salary": "96000.00"
#   },
#   {
#     "id": 47,
#     "name": "Meena Das",
#     "email": "meena.das@company.com",
#     "department": "AI",
#     "salary": "97000.00"
#   },
#   {
#     "id": 50,
#     "name": "Priya Reddy",
#     "email": "priya.reddy@company.com",
#     "department": "AI",
#     "salary": "95000.00"
#   }
# ]

# %%
query = "Show me all projects that are currently In Progress?"

result = agent.process_query(query)

print(f"> Query: {query}")
print(f"> Answer: {result.get('explanation')}")
print(f"> Data: {json.dumps(result.get('data'), indent=2, default=str)}")
# Out:
# 2026-02-12 09:28:44,652 | INFO | app.agents.planner_agent | Planning for query: 'Show me all projects that are currently In Progress?'
# 2026-02-12 09:28:44,655 | INFO | app.agents.llm_provider | Ollama (llama3): Generating...
# 2026-02-12 09:30:40,509 | INFO | app.agents.planner_agent | Selected tool: get_projects_by_status with params: {'status': 'In Progress'}
# 2026-02-12 09:30:40,510 | INFO | app.agents.executor_agent | Executing tool: get_projects_by_status
# 2026-02-12 09:30:40,512 | INFO | app.mcp.tools | Tool: Get projects (status=In Progress)
# 2026-02-12 09:30:40,513 | INFO | app.database.db_executor | Executing SQL: SELECT id, name, description, status, start_date, end_date, budget FROM projects WHERE LOWER(status) = LOWER(%s) | Params: ('In Progress',)
# 2026-02-12 09:30:40,519 | INFO | app.database.db_executor | Query returned 11 rows
# 2026-02-12 09:30:40,520 | INFO | app.agents.reasoner_agent | Generating explanation...
# 2026-02-12 09:30:40,522 | INFO | app.agents.llm_provider | Ollama (llama3): Generating...
# 2026-02-12 09:43:34,220 | ERROR | app.agents.llm_provider | Ollama failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# 2026-02-12 09:43:34,331 | ERROR | app.agents.reasoner_agent | Reasoning failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# > Query: Show me all projects that are currently In Progress?
# > Answer: Here is the raw data: [{'id': 1, 'name': 'AI Model Development', 'description': 'Developing ML models for prediction', 'status': 'In Progress', 'start_date': datetime.date(2023, 1, 1), 'end_date': datetime.date(2024, 12, 31), 'budget': Decimal('500000.00')}, {'id': 3, 'name': 'Infrastructure Migration', 'description': 'Migrating to cloud infrastructure', 'status': 'In Progress', 'start_date': datetime.date(2023, 3, 1), 'end_date': datetime.date(2024, 6, 30), 'budget': Decimal('300000.00')}, {'id': 5, 'name': 'AI Model Development', 'description': 'Developing ML models for predictive analytics', 'status': 'In Progress', 'start_date': datetime.date(2023, 1, 1), 'end_date': datetime.date(2024, 12, 31), 'budget': Decimal('500000.00')}, {'id': 7, 'name': 'Infrastructure Migration', 'description': 'Migrating on-prem systems to cloud', 'status': 'In Progress', 'start_date': datetime.date(2023, 3, 1), 'end_date': datetime.date(2024, 6, 30), 'budget': Decimal('300000.00')}, {'id': 9, 'name': 'Customer Analytics Platform', 'description': 'Customer behavior analysis using BI tools', 'status': 'In Progress', 'start_date': datetime.date(2023, 5, 10), 'end_date': datetime.date(2024, 11, 30), 'budget': Decimal('250000.00')}, {'id': 12, 'name': 'AI Chatbot', 'description': 'Customer support chatbot using NLP', 'status': 'In Progress', 'start_date': datetime.date(2023, 7, 1), 'end_date': datetime.date(2024, 9, 30), 'budget': Decimal('220000.00')}, {'id': 14, 'name': 'Data Warehouse Setup', 'description': 'Centralized data warehouse creation', 'status': 'In Progress', 'start_date': datetime.date(2023, 4, 1), 'end_date': datetime.date(2024, 8, 31), 'budget': Decimal('280000.00')}, {'id': 16, 'name': 'API Gateway Implementation', 'description': 'Unified API gateway for microservices', 'status': 'In Progress', 'start_date': datetime.date(2023, 6, 15), 'end_date': datetime.date(2024, 3, 31), 'budget': Decimal('160000.00')}, {'id': 18, 'name': 'AI Recommendation Engine', 'description': 'Personalized recommendation system', 'status': 'In Progress', 'start_date': datetime.date(2023, 8, 1), 'end_date': datetime.date(2024, 12, 15), 'budget': Decimal('330000.00')}, {'id': 21, 'name': 'Employee Performance System', 'description': 'Performance tracking and KPI system', 'status': 'In Progress', 'start_date': datetime.date(2023, 9, 1), 'end_date': datetime.date(2024, 10, 31), 'budget': Decimal('175000.00')}, {'id': 24, 'name': 'Log Analytics Platform', 'description': 'Centralized log analytics solution', 'status': 'In Progress', 'start_date': datetime.date(2023, 10, 1), 'end_date': datetime.date(2024, 12, 31), 'budget': Decimal('260000.00')}]
# > Data: [
#   {
#     "id": 1,
#     "name": "AI Model Development",
#     "description": "Developing ML models for prediction",
#     "status": "In Progress",
#     "start_date": "2023-01-01",
#     "end_date": "2024-12-31",
#     "budget": "500000.00"
#   },
#   {
#     "id": 3,
#     "name": "Infrastructure Migration",
#     "description": "Migrating to cloud infrastructure",
#     "status": "In Progress",
#     "start_date": "2023-03-01",
#     "end_date": "2024-06-30",
#     "budget": "300000.00"
#   },
#   {
#     "id": 5,
#     "name": "AI Model Development",
#     "description": "Developing ML models for predictive analytics",
#     "status": "In Progress",
#     "start_date": "2023-01-01",
#     "end_date": "2024-12-31",
#     "budget": "500000.00"
#   },
#   {
#     "id": 7,
#     "name": "Infrastructure Migration",
#     "description": "Migrating on-prem systems to cloud",
#     "status": "In Progress",
#     "start_date": "2023-03-01",
#     "end_date": "2024-06-30",
#     "budget": "300000.00"
#   },
#   {
#     "id": 9,
#     "name": "Customer Analytics Platform",
#     "description": "Customer behavior analysis using BI tools",
#     "status": "In Progress",
#     "start_date": "2023-05-10",
#     "end_date": "2024-11-30",
#     "budget": "250000.00"
#   },
#   {
#     "id": 12,
#     "name": "AI Chatbot",
#     "description": "Customer support chatbot using NLP",
#     "status": "In Progress",
#     "start_date": "2023-07-01",
#     "end_date": "2024-09-30",
#     "budget": "220000.00"
#   },
#   {
#     "id": 14,
#     "name": "Data Warehouse Setup",
#     "description": "Centralized data warehouse creation",
#     "status": "In Progress",
#     "start_date": "2023-04-01",
#     "end_date": "2024-08-31",
#     "budget": "280000.00"
#   },
#   {
#     "id": 16,
#     "name": "API Gateway Implementation",
#     "description": "Unified API gateway for microservices",
#     "status": "In Progress",
#     "start_date": "2023-06-15",
#     "end_date": "2024-03-31",
#     "budget": "160000.00"
#   },
#   {
#     "id": 18,
#     "name": "AI Recommendation Engine",
#     "description": "Personalized recommendation system",
#     "status": "In Progress",
#     "start_date": "2023-08-01",
#     "end_date": "2024-12-15",
#     "budget": "330000.00"
#   },
#   {
#     "id": 21,
#     "name": "Employee Performance System",
#     "description": "Performance tracking and KPI system",
#     "status": "In Progress",
#     "start_date": "2023-09-01",
#     "end_date": "2024-10-31",
#     "budget": "175000.00"
#   },
#   {
#     "id": 24,
#     "name": "Log Analytics Platform",
#     "description": "Centralized log analytics solution",
#     "status": "In Progress",
#     "start_date": "2023-10-01",
#     "end_date": "2024-12-31",
#     "budget": "260000.00"
#   }
# ]

# %%
query = "Show me who will get the salary more than 90000?"

result = agent.process_query(query)

print(f"> Query: {query}")
print(f"> Answer: {result.get('explanation')}")
print(f"> Data: {json.dumps(result.get('data'), indent=2, default=str)}")
# Out:
# 2026-02-12 10:46:20,730 | INFO | app.agents.planner_agent | Planning for query: 'Show me who will get the salary more than 90000?'
# 2026-02-12 10:46:20,734 | INFO | app.agents.llm_provider | Ollama (llama3): Generating...
# 2026-02-12 10:47:44,630 | INFO | app.agents.planner_agent | Selected tool: run_sql_query with params: {'query': 'SELECT e.name, e.salary FROM employees e WHERE e.salary > 90000;'}
# 2026-02-12 10:47:44,633 | INFO | app.agents.executor_agent | Executing tool: run_sql_query
# 2026-02-12 10:47:44,634 | INFO | app.mcp.tools | Tool: Run SQL Query
# 2026-02-12 10:47:44,635 | INFO | app.database.db_executor | Executing SQL: SELECT e.name, e.salary FROM employees e WHERE e.salary > 90000; | Params: None
# 2026-02-12 10:47:44,640 | INFO | app.database.db_executor | Query returned 22 rows
# 2026-02-12 10:47:44,643 | INFO | app.agents.reasoner_agent | Generating explanation...
# 2026-02-12 10:47:44,645 | INFO | app.agents.llm_provider | Ollama (llama3): Generating...
# > Query: Show me who will get the salary more than 90000?
# > Answer: Based on the provided database result, there are five individuals who will receive a salary of more than $90,000: Alice Johnson ($95,000), Eva Martinez ($98,000 and $98,000), Mona Scott ($97,000), Queen Roberts ($99,000), and Yara Khan ($96,500). These individuals are the top earners in the dataset.
# > Data: [
#   {
#     "name": "Alice Johnson",
#     "salary": "95000.00"
#   },
#   {
#     "name": "Bob Smith",
#     "salary": "92000.00"
#   },
#   {
#     "name": "Eva Martinez",
#     "salary": "98000.00"
#   },
#   {
#     "name": "Alice Johnson",
#     "salary": "95000.00"
#   },
#   {
#     "name": "Bob Smith",
#     "salary": "92000.00"
#   },
#   {
#     "name": "Eva Martinez",
#     "salary": "98000.00"
#   },
#   {
#     "name": "Irene Adams",
#     "salary": "96000.00"
#   },
#   {
#     "name": "Leo Parker",
#     "salary": "91000.00"
#   },
#   {
#     "name": "Mona Scott",
#     "salary": "97000.00"
#   },
#   {
#     "name": "Paul King",
#     "salary": "90500.00"
#   },
#   {
#     "name": "Queen Roberts",
#     "salary": "99000.00"
#   },
#   {
#     "name": "Tom Harris",
#     "salary": "91500.00"
#   },
#   {
#     "name": "Uma Patel",
#     "salary": "94000.00"
#   },
#   {
#     "name": "Xavier Brooks",
#     "salary": "92000.00"
#   },
#   {
#     "name": "Yara Khan",
#     "salary": "96500.00"
#   },
#   {
#     "name": "Amit Sharma",
#     "salary": "93000.00"
#   },
#   {
#     "name": "Deepak Verma",
#     "salary": "91000.00"
#   },
#   {
#     "name": "Esha Mehta",
#     "salary": "95500.00"
#   },
#   {
#     "name": "Isha Kapoor",
#     "salary": "96000.00"
#   },
#   {
#     "name": "Lalit Choudhary",
#     "salary": "92500.00"
#   },
#   {
#     "name": "Meena Das",
#     "salary": "97000.00"
#   },
#   {
#     "name": "Priya Reddy",
#     "salary": "95000.00"
#   }
# ]

# %%
query = "Show me all projects that are Completed?"

result = agent.process_query(query)

print(f"> Query: {query}")
print(f"> Answer: {result.get('explanation')}")
print(f"> Data: {json.dumps(result.get('data'), indent=2, default=str)}")
# Out:
# 2026-02-12 10:05:34,576 | INFO | app.agents.planner_agent | Planning for query: 'Show me all projects that are Completed?'
# 2026-02-12 10:05:34,578 | INFO | app.agents.llm_provider | Ollama (llama3): Generating...
# 2026-02-12 10:08:36,648 | ERROR | app.agents.llm_provider | Ollama failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# 2026-02-12 10:08:36,650 | ERROR | app.agents.planner_agent | Planning failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# 2026-02-12 10:08:36,653 | INFO | app.agents.executor_agent | Executing tool: get_projects_by_status
# 2026-02-12 10:08:36,654 | INFO | app.mcp.tools | Tool: Get projects (status=In Progress)
# 2026-02-12 10:08:36,655 | INFO | app.database.db_executor | Executing SQL: SELECT id, name, description, status, start_date, end_date, budget FROM projects WHERE LOWER(status) = LOWER(%s) | Params: ('In Progress',)
# 2026-02-12 10:08:36,659 | INFO | app.database.db_executor | Query returned 11 rows
# 2026-02-12 10:08:36,660 | INFO | app.agents.reasoner_agent | Generating explanation...
# 2026-02-12 10:08:36,662 | INFO | app.agents.llm_provider | Ollama (llama3): Generating...
# 2026-02-12 10:11:38,711 | ERROR | app.agents.llm_provider | Ollama failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# 2026-02-12 10:11:38,713 | ERROR | app.agents.reasoner_agent | Reasoning failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# > Query: Show me all projects that are Completed?
# > Answer: Here is the raw data: [{'id': 1, 'name': 'AI Model Development', 'description': 'Developing ML models for prediction', 'status': 'In Progress', 'start_date': datetime.date(2023, 1, 1), 'end_date': datetime.date(2024, 12, 31), 'budget': Decimal('500000.00')}, {'id': 3, 'name': 'Infrastructure Migration', 'description': 'Migrating to cloud infrastructure', 'status': 'In Progress', 'start_date': datetime.date(2023, 3, 1), 'end_date': datetime.date(2024, 6, 30), 'budget': Decimal('300000.00')}, {'id': 5, 'name': 'AI Model Development', 'description': 'Developing ML models for predictive analytics', 'status': 'In Progress', 'start_date': datetime.date(2023, 1, 1), 'end_date': datetime.date(2024, 12, 31), 'budget': Decimal('500000.00')}, {'id': 7, 'name': 'Infrastructure Migration', 'description': 'Migrating on-prem systems to cloud', 'status': 'In Progress', 'start_date': datetime.date(2023, 3, 1), 'end_date': datetime.date(2024, 6, 30), 'budget': Decimal('300000.00')}, {'id': 9, 'name': 'Customer Analytics Platform', 'description': 'Customer behavior analysis using BI tools', 'status': 'In Progress', 'start_date': datetime.date(2023, 5, 10), 'end_date': datetime.date(2024, 11, 30), 'budget': Decimal('250000.00')}, {'id': 12, 'name': 'AI Chatbot', 'description': 'Customer support chatbot using NLP', 'status': 'In Progress', 'start_date': datetime.date(2023, 7, 1), 'end_date': datetime.date(2024, 9, 30), 'budget': Decimal('220000.00')}, {'id': 14, 'name': 'Data Warehouse Setup', 'description': 'Centralized data warehouse creation', 'status': 'In Progress', 'start_date': datetime.date(2023, 4, 1), 'end_date': datetime.date(2024, 8, 31), 'budget': Decimal('280000.00')}, {'id': 16, 'name': 'API Gateway Implementation', 'description': 'Unified API gateway for microservices', 'status': 'In Progress', 'start_date': datetime.date(2023, 6, 15), 'end_date': datetime.date(2024, 3, 31), 'budget': Decimal('160000.00')}, {'id': 18, 'name': 'AI Recommendation Engine', 'description': 'Personalized recommendation system', 'status': 'In Progress', 'start_date': datetime.date(2023, 8, 1), 'end_date': datetime.date(2024, 12, 15), 'budget': Decimal('330000.00')}, {'id': 21, 'name': 'Employee Performance System', 'description': 'Performance tracking and KPI system', 'status': 'In Progress', 'start_date': datetime.date(2023, 9, 1), 'end_date': datetime.date(2024, 10, 31), 'budget': Decimal('175000.00')}, {'id': 24, 'name': 'Log Analytics Platform', 'description': 'Centralized log analytics solution', 'status': 'In Progress', 'start_date': datetime.date(2023, 10, 1), 'end_date': datetime.date(2024, 12, 31), 'budget': Decimal('260000.00')}]
# > Data: [
#   {
#     "id": 1,
#     "name": "AI Model Development",
#     "description": "Developing ML models for prediction",
#     "status": "In Progress",
#     "start_date": "2023-01-01",
#     "end_date": "2024-12-31",
#     "budget": "500000.00"
#   },
#   {
#     "id": 3,
#     "name": "Infrastructure Migration",
#     "description": "Migrating to cloud infrastructure",
#     "status": "In Progress",
#     "start_date": "2023-03-01",
#     "end_date": "2024-06-30",
#     "budget": "300000.00"
#   },
#   {
#     "id": 5,
#     "name": "AI Model Development",
#     "description": "Developing ML models for predictive analytics",
#     "status": "In Progress",
#     "start_date": "2023-01-01",
#     "end_date": "2024-12-31",
#     "budget": "500000.00"
#   },
#   {
#     "id": 7,
#     "name": "Infrastructure Migration",
#     "description": "Migrating on-prem systems to cloud",
#     "status": "In Progress",
#     "start_date": "2023-03-01",
#     "end_date": "2024-06-30",
#     "budget": "300000.00"
#   },
#   {
#     "id": 9,
#     "name": "Customer Analytics Platform",
#     "description": "Customer behavior analysis using BI tools",
#     "status": "In Progress",
#     "start_date": "2023-05-10",
#     "end_date": "2024-11-30",
#     "budget": "250000.00"
#   },
#   {
#     "id": 12,
#     "name": "AI Chatbot",
#     "description": "Customer support chatbot using NLP",
#     "status": "In Progress",
#     "start_date": "2023-07-01",
#     "end_date": "2024-09-30",
#     "budget": "220000.00"
#   },
#   {
#     "id": 14,
#     "name": "Data Warehouse Setup",
#     "description": "Centralized data warehouse creation",
#     "status": "In Progress",
#     "start_date": "2023-04-01",
#     "end_date": "2024-08-31",
#     "budget": "280000.00"
#   },
#   {
#     "id": 16,
#     "name": "API Gateway Implementation",
#     "description": "Unified API gateway for microservices",
#     "status": "In Progress",
#     "start_date": "2023-06-15",
#     "end_date": "2024-03-31",
#     "budget": "160000.00"
#   },
#   {
#     "id": 18,
#     "name": "AI Recommendation Engine",
#     "description": "Personalized recommendation system",
#     "status": "In Progress",
#     "start_date": "2023-08-01",
#     "end_date": "2024-12-15",
#     "budget": "330000.00"
#   },
#   {
#     "id": 21,
#     "name": "Employee Performance System",
#     "description": "Performance tracking and KPI system",
#     "status": "In Progress",
#     "start_date": "2023-09-01",
#     "end_date": "2024-10-31",
#     "budget": "175000.00"
#   },
#   {
#     "id": 24,
#     "name": "Log Analytics Platform",
#     "description": "Centralized log analytics solution",
#     "status": "In Progress",
#     "start_date": "2023-10-01",
#     "end_date": "2024-12-31",
#     "budget": "260000.00"
#   }
# ]

# %%
query = "What is the total budget of all in-progress projects?"

result = agent.process_query(query)

print(f"> Query: {query}")
print(f"> Answer: {result.get('explanation')}")
print(f"> Data: {json.dumps(result.get('data'), indent=2, default=str)}")
